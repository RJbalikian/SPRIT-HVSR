# %%
# !python.exe -m pip install --upgrade pip
# Out:
# Requirement already satisfied: plotly in c:\users\riley\localdata\virtual_envs\seismic310_venv\lib\site-packages (5.18.0)
# Collecting ipywidgets
#   Obtaining dependency information for ipywidgets from https://files.pythonhosted.org/packages/4a/0e/57ed498fafbc60419a9332d872e929879ceba2d73cb11d284d7112472b3e/ipywidgets-8.1.1-py3-none-any.whl.metadata
#   Using cached ipywidgets-8.1.1-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\riley\localdata\virtual_envs\seismic310_venv\lib\site-packages (from plotly) (8.2.3)
# Requirement already satisfied: packaging in c:\users\riley\localdata\virtual_envs\seismic310_venv\lib\site-packages (from plotly) (23.1)
# Requirement already satisfied: comm>=0.1.3 in c:\users\riley\localdata\virtual_envs\seismic310_venv\lib\site-packages (from ipywidgets) (0.1.3)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\riley\localdata\virtual_envs\seismic310_venv\lib\site-packages (from ipywidgets) (8.13.2)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\riley\localdata\virtual_envs\seismic310_venv\lib\site-packages (from ipywidgets) (5.9.0)
# Requirement already satisfied: widgetsnbextension~=4.0.9 in c:\users\riley\localdata\virtual_envs\seismic310_venv\lib\site-packages (from ipywidgets) (4.0.9)
# Requirement already satisfied: jupyterlab-widgets~=3.0.9 in c:\users\riley\localdata\virtual_envs\seismic310_venv\lib\site-packages (from ipywidgets) (3.0.9)
# Requirement already satisfied: backcall in c:\users\riley\localdata\virtual_envs\seismic310_venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: decorator in c:\users\riley\localdata\virtual_envs\seismic310_venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\riley\localdata\virtual_envs\seismic310_venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.18.2)
# Requirement already satisfied: matplotlib-inline in c:\users\riley\localdata\virtual_envs\seismic310_venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.1.6)
# Requirement already satisfied: pickleshare in c:\users\riley\localdata\virtual_envs\seismic310_venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\riley\localdata\virtual_envs\seismic310_venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.38)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\riley\localdata\virtual_envs\seismic310_venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\riley\localdata\virtual_envs\seismic310_venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.2)
# Requirement already satisfied: colorama in c:\users\riley\localdata\virtual_envs\seismic310_venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\riley\localdata\virtual_envs\seismic310_venv\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\riley\localdata\virtual_envs\seismic310_venv\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets) (0.2.6)
# Requirement already satisfied: executing>=1.2.0 in c:\users\riley\localdata\virtual_envs\seismic310_venv\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\riley\localdata\virtual_envs\seismic310_venv\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: pure-eval in c:\users\riley\localdata\virtual_envs\seismic310_venv\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: six in c:\users\riley\localdata\virtual_envs\seismic310_venv\lib\site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)
# Using cached ipywidgets-8.1.1-py3-none-any.whl (139 kB)
# Installing collected packages: ipywidgets
# Successfully installed ipywidgets-8.1.1
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import plotly.graph_objs as go
import ipywidgets as widgets
from IPython.display import display

# Create the Input tab
input_tab = widgets.Textarea(
    value='',
    placeholder='Enter input parameters here...',
    description='Input:',
    disabled=False
)

# Create the Preview tab
preview_fig = go.FigureWidget()
preview_tab = widgets.Output()
with preview_tab:
    display(preview_fig)

# Create the PPSD Settings subtab
ppsd_settings_tab = widgets.Textarea(
    value='',
    placeholder='Enter PPSD settings here...',
    description='PPSD Settings:',
    disabled=False
)

# Create the HVSR Settings subtab
hvsr_settings_tab = widgets.Textarea(
    value='',
    placeholder='Enter HVSR settings here...',
    description='HVSR Settings:',
    disabled=False
)

# Create the Plot Settings subtab
plot_settings_tab = widgets.Textarea(
    value='',
    placeholder='Enter plot settings here...',
    description='Plot Settings:',
    disabled=False
)

# Create the Curve Analysis subtab
curve_fig = go.FigureWidget()
curve_analysis_tab = widgets.Output()
with curve_analysis_tab:
    display(curve_fig)

# Create the Report subtab
report_fig = go.FigureWidget()
report_tab = widgets.Output()
with report_tab:
    display(report_fig)

# Create the Settings tab with subtabs
settings_tab = widgets.Tab()
settings_tab.children = [ppsd_settings_tab, hvsr_settings_tab, plot_settings_tab]
settings_tab.set_title(0, 'PPSD Settings')
settings_tab.set_title(1, 'HVSR Settings')
settings_tab.set_title(2, 'Plot Settings')

# Create the Results tab with subtabs
results_tab = widgets.Tab()
results_tab.children = [curve_analysis_tab, report_tab]
results_tab.set_title(0, 'Curve Analysis')
results_tab.set_title(1, 'Report')

# Create the main tab widget
sprit_widget = widgets.Tab()
sprit_widget.children = [input_tab, preview_tab, settings_tab, widgets.Output(), results_tab]
sprit_widget.set_title(0, 'Input')
sprit_widget.set_title(1, 'Preview')
sprit_widget.set_title(2, 'Settings')
sprit_widget.set_title(3, 'Log')
sprit_widget.set_title(4, 'Results')

# Display the tab widget
display(sprit_widget)
